# %%
'''
This code demonstrates the use of plotting techniques in python using matplotlib, pandas, and numpy libraries.
Data will be passed using read_csv method or will be created in this code.
'''
#importing the neccessary libraries that are going to be used int his demonstration
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#first data to work with
df = pd.DataFrame(pd.read_csv('data\purchases.csv'))
df
# Out:
#   Unnamed: 0 country  ad_views  items_purchased
# 0     George      US        16                2
# 1       John     CAN        42                1
# 2     Thomas     CAN        32                0
# 3      James      US        13                8
# 4     Andrew     CAN        63                0
# 5     Martin      US        19                5
# 6    William      US        65                7
# 7    Zachary      US        23                3
# 8    Millard     CAN        16                0
# 9   Franklin      US        77                5

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(df['ad_views'],color='green')
plt.xlabel('Advertisement Views by customer')
plt.ylabel('Customer Views')
plt.title('Advertizment conversion rate')

plt.subplot(1, 2, 2)
plt.plot(df['ad_views']**2, color='purple')
plt.ylabel('ad_views squared')
plt.title('Square of ad views')
plt.tight_layout()

# %%
'''These two graphs shown above, represent how many times each customer viewd posted advertizement posted and was able to 
take the next stape in purchasing the equipment advertized. The green graph is just representation of number of times
a customer viewed the add (x) and purchased (y) without data manipulation.The purple graph is the squared values of ad_views to
show how the graph changes. We can see from between 1 and 3 the line flattens to straight line and the gup widens on top. 
'''

# %%
#Lets look at another set of data
data = pd.read_csv('data/UNdata_international_bribary.csv')
df1 = pd.DataFrame(data)

del df1['Value Footnotes'] #This column has nothing usable but all NAN
df1_1 = df1.sample(10)
df1_1
# Out:
#                 Country or Area  Year      Value
# 138                      Kosovo  2013  13.700000
# 269                        Togo  2016   7.000000
# 284                  Uzbekistan  2013   7.000000
# 73   Early-demographic dividend  2017  16.977778
# 225    Pre-demographic dividend  2017  29.160714
# 248                 South Sudan  2014  48.000000
# 133                      Jordan  2006   3.200000
# 92                     Ethiopia  2015  26.800000
# 121                   IBRD only  2017  13.655357
# 145   Late-demographic dividend  2017  14.602857

# %%
#At first glance lets see what the sample data tells us about the report
x = df1_1.groupby('Country or Area')
x1 = x['Year']
plt.hist(x1, color='purple')
#plt.title('Sample data 10 reports taken randomely\n');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-176-4973b63117fa> in <module>
#       2 x = df1_1.groupby('Country or Area')
#       3 x1 = x['Year']
# ----> 4 plt.hist(x1, color='purple')
#       5 #plt.title('Sample data 10 reports taken randomely\n');
#
# c:\users\afewerk\appdata\local\programs\python\python36\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2659         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2660         color=color, label=label, stacked=stacked, normed=normed,
# -> 2661         **({"data": data} if data is not None else {}), **kwargs)
#    2662
#    2663
#
# ...

# %%
#lets see the data with visualization
x = df1['Year']
plt.hist(x, color = 'green')
plt.title('UN 2006 to 2016 International Bribary Report\n')
plt.ylabel('Bribary Percentage')
plt.xlabel('Report year');

# %%
'''The graph above shows a decade bribary data collected by the United Nations from countries accross the world. 
To dig deaper, the total of 2006 data shows great deal of bribary report and falls back to below 10 for the year b/w 2007 to 2008.
We can see that the overal report has been increasing from the start of the report in 2006 to 2016. We can also tell, the total
report collected for years b/n 2010 to 2013, 2014-205 shows much smaller magnitude than other years. The span b/n 
the repor years is increasing which makes data accuracy much difficult to predict. 
'''
